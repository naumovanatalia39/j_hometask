# %% [markdown]
# Условие 1: Задача 1
# Постройте график
# Назовите график
# Сделайте именование оси x и оси y
# Сделайте выводы
#
# 1.1. Скачать следующие данные: kc-house-data и laptop_price
#
# 1.2. Изучите стоимости недвижимости
#
# 1.3. Изучите распределение квадратуры жилой
#
# 1.4. Изучите распределение года постройки

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('kc-house-data.csv', encoding = 'latin-1')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# 1.2. Изучите стоимости недвижимости
#
# Больше домов по невысокой цене

# %%
plt.hist(df['price'])
plt.xlabel('euro')
plt.ylabel('Count')
plt.title('Количество по цене')
# Out:
# Text(0.5, 1.0, 'Количество по цене')

# %% [markdown]
# 1.3. Изучите распределение квадратуры жилой
#
# Больше домов с небольшой и средней площадью жилой

# %%
plt.hist(df['sqft_living'])
plt.xlabel('sqft')
plt.ylabel('Count')
plt.title('Количество по квадратуре жилой')
# Out:
# Text(0.5, 1.0, 'Количество по квадратуре жилой')

# %% [markdown]
# 1.4. Изучите распределение года постройки
#
# Больше новых домов, чем старых.

# %%
plt.hist(df['yr_built'])
plt.xlabel('year')
plt.ylabel('Count')
plt.title('Количество по году постройки')
# Out:
# Text(0.5, 1.0, 'Количество по году постройки')

# %% [markdown]
# 2.1. Изучите распределение домов от наличия вида на набережную
#
# Постройте график
#
# Сделайте выводы
#
# 2.2. Изучите распределение этажей домов
#
# 2.3. Изучите распределение состояния домов

# %%
data = df['waterfront'].value_counts()
data
# Out:
# waterfront
# 0    21450
# 1      163
# Name: count, dtype: int64

# %% [markdown]
# Меньше 1% домов с видом на набережную, большинство без вида.

# %%
plt.pie(data.values, labels = data.index, autopct='%1.2f%%');

# %% [markdown]
# 2.2. Изучите распределение этажей домов

# %%
data = df['floors'].value_counts()
data
# Out:
# floors
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64

# %% [markdown]
# Больше всего одно и двух этажных домов

# %%
plt.bar(data.index, data.values)
plt.xticks(rotation = 50);

# %% [markdown]
# 2.3. Изучите распределение состояния домов

# %%
data = df['condition'].value_counts()
data
# Out:
# condition
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: count, dtype: int64

# %% [markdown]
# Больше всего домов в среднем и выше среднего состоянии. В очень плохом состоянии совсем  мало домов.

# %%
plt.pie(data.values, labels = data.index, autopct='%1.2f%%');
plt.legend(data.index)

# %% [markdown]
# Условие 3: 3 задача
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
import seaborn as sns
sns.boxplot(x=df['waterfront'], y=df['price'], showfliers=False)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %% [markdown]
# цена квартир с видом на набережную дороже

# %%
import seaborn as sns
sns.boxplot(x=df['bedrooms'], y=df['price'], showfliers=False)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# самая высокая цена у домов с 8 спальнями, медианная стоимость примерно одинакова у домов от 5 до 8 спален и у 0-3 спален

# %%
sns.boxplot(x=df['floors'], y=df['price'], showfliers=False)
# Out:
# <Axes: xlabel='floors', ylabel='price'>

# %% [markdown]
# Дома с 2,5 этажами стоят дороже всего, дома с 1,5, 2, 3 и 3,5 этажами стоят примерно одинаково. Дешевле всего одноэтажные дома.

# %%
sns.boxplot(x=df['condition'], y=df['price'], showfliers=False)
# Out:
# <Axes: xlabel='condition', ylabel='price'>

# %% [markdown]
# Дома в состоянии средний, выше среднего и отличном имеют примерно одинаковую медианную стоимость, причем дома среднего состояния стоят даже немного дороже, чем дома выше среднего состояния.

# %%
sns.boxplot(x=df['view'], y=df['price'], showfliers=False)
# Out:
# <Axes: xlabel='view', ylabel='price'>

# %% [markdown]
# Дома с очень красивым видом стоят дороже, с видом от 1 до 3 примерно одинакова медианная стоимость.
